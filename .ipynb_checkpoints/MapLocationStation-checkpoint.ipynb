# %%
import csv
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import descartes
from shapely.geometry import Point, Polygon

#Load in the CSV Bike Station Location Data
df = pd.read_csv('HRSQ12020.csv')

#combine the latitude and longitude to make coordinates
df['coordinates'] = df[['Longitude', 'Latitude']].values.tolist()

# Change the coordinates to a geoPoint
df['coordinates'] = df['coordinates'].apply(Point)
df.head()
# Out:
#    Station #                               Station Name  # of Racks  \
# 0       1000                   Liberty Ave & Stanwix St          16
# 1       1001                 Forbes Ave & Market Square          19
# 2       1002                        Third Ave & Wood St          15
# 3       1003  First Ave & Smithfield St (Art Institute)          15
# 4       1004               First Ave & B St (T Station)          15
#
#     Latitude  Longitude                           coordinates
# 0  40.441326 -80.004679  POINT (-80.00467900000001 40.441326)
# 1  40.440877 -80.003080  POINT (-80.00308000000001 40.440877)
# 2  40.439030 -80.001860   POINT (-80.00185999999999 40.43903)
# 3  40.437200 -80.000375    POINT (-80.00037500000001 40.4372)
# 4  40.435887 -79.997102          POINT (-79.997102 40.435887)

# %%
#fixing wrong negative value for Latitude
df.loc[df["Latitude"] == df["Latitude"].min()]
df.at[80, 'Latitude'] = 40.467715

# %%
#convert df to a geodf
crs = "epsg:4269"
gdf = gpd.GeoDataFrame(df, crs = crs, geometry='coordinates')
gdf.head()
# Out:
#    Station #                               Station Name  # of Racks  \
# 0       1000                   Liberty Ave & Stanwix St          16
# 1       1001                 Forbes Ave & Market Square          19
# 2       1002                        Third Ave & Wood St          15
# 3       1003  First Ave & Smithfield St (Art Institute)          15
# 4       1004               First Ave & B St (T Station)          15
#
#     Latitude  Longitude                 coordinates
# 0  40.441326 -80.004679  POINT (-80.00468 40.44133)
# 1  40.440877 -80.003080  POINT (-80.00308 40.44088)
# 2  40.439030 -80.001860  POINT (-80.00186 40.43903)
# 3  40.437200 -80.000375  POINT (-80.00038 40.43720)
# 4  40.435887 -79.997102  POINT (-79.99710 40.43589)

# %%
#plot the geodf
#not working for some reason, fix later
gdf.plot()

# %%
plt.scatter(df['Longitude'], df['Latitude'])
plt.show()

# %%
#Plot the Pittsburgh Neighborhoods
pittMap = gpd.read_file('Neighborhoods/ecc95d19-e9fb-46a3-be05-e7e103f362a52020328-1-565pof.jnegf.shp')
pittMap.plot()

# %%
#Use matplotlib to plot the pittsburgh neighborhoods
fig, ax = plt.subplots(1, figsize=(10, 8))
ax.set_position([0,0,1,1])   # Puts axis to edge of figure
lims = plt.axis('equal')
ax.set_aspect('equal')
pittMap.plot(ax = ax, color='white', edgecolor='black')
#geopandas plotting was not working, so I just plotted the scatter plot on top of the map for now...
plt.scatter(df['Longitude'], df['Latitude'], 15, marker='o', color='Blue')
plt.show()

# %%
#Make the points from our dataframe bike station locations
#specify coordinate reference system and make GeoDataFrame
crs = "epsg:4326"
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = gpd.GeoDataFrame(df, crs = crs, geometry = geometry)
