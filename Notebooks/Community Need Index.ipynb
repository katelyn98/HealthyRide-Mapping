# %%
import pandas as pd

# %%
cni_df = pd.read_excel(open("../Data/data-set-for-2014-Community-Need-Index-release_version_v1.xlsx",'rb'), sheet_name = '2014_CommunityNeedIndex')

# %%
cni_df
# Out:
#                        Id          Id2  Tract_Shorthand  \
# 0    1400000US42003564100  42003564100          5641.00
# 1    1400000US42003456003  42003456003          4560.03
# 2    1400000US42003474201  42003474201          4742.01
# 3    1400000US42003473500  42003473500          4735.00
# 4    1400000US42003409000  42003409000          4090.00
# ..                    ...          ...              ...
# 260  1400000US42003514000  42003514000          5140.00
# 261  1400000US42003550900  42003550900          5509.00
# 262  1400000US42003512800  42003512800          5128.00
# 263  1400000US42003513800  42003513800          5138.00
# 264  1400000US42003552100  42003552100          5521.00
#
#     Neighborhood_Municipality Additional_NeighMunis  Pop_Estimate  Tier  \
# 0               ROSSLYN FARMS             THORNBURG           983     1
# 1               SOUTH FAYETTE                   NaN          6726     1
# 2           UPPER SAINT CLAIR                   NaN          2522     1
# ...

# %%
cni_df.dtypes
# Out:
# Id                            object
# Id2                            int64
# Tract_Shorthand              float64
# Neighborhood_Municipality     object
# Additional_NeighMunis         object
# Pop_Estimate                   int64
# Tier                           int64
# AverageRank                  float64
# Pov_14                       float64
# Pov200_14                    float64
# FHF_14                       float64
# MaleLF_14                    float64
# Vacant_14                    float64
# NoVehicle_14                 float64
# HSDegree25_14                float64
# Pov_14Rank                     int64
# Pov200_14Rank                  int64
# FHF_14Rank                     int64
# MaleLF_14Rank                  int64
# Vacant_14Rank                  int64
# NoVehicle_14Rank               int64
# HSDegree25_14Rank              int64
# Unnamed: 22                  float64
# dtype: object

# %%
cni_df['Tract_Shorthand'] = cni_df.Tract_Shorthand.astype(int)
cni_df
# Out:
#                        Id          Id2  Tract_Shorthand  \
# 0    1400000US42003564100  42003564100             5641
# 1    1400000US42003456003  42003456003             4560
# 2    1400000US42003474201  42003474201             4742
# 3    1400000US42003473500  42003473500             4735
# 4    1400000US42003409000  42003409000             4090
# ..                    ...          ...              ...
# 260  1400000US42003514000  42003514000             5140
# 261  1400000US42003550900  42003550900             5509
# 262  1400000US42003512800  42003512800             5128
# 263  1400000US42003513800  42003513800             5138
# 264  1400000US42003552100  42003552100             5521
#
#     Neighborhood_Municipality Additional_NeighMunis  Pop_Estimate  Tier  \
# 0               ROSSLYN FARMS             THORNBURG           983     1
# 1               SOUTH FAYETTE                   NaN          6726     1
# 2           UPPER SAINT CLAIR                   NaN          2522     1
# ...

# %%
# Out:
#                        Id          Id2  Tract_Shorthand  \
# 0    1400000US42003564100  42003564100          5641.00
# 1    1400000US42003456003  42003456003          4560.03
# 2    1400000US42003474201  42003474201          4742.01
# 3    1400000US42003473500  42003473500          4735.00
# 4    1400000US42003409000  42003409000          4090.00
# ..                    ...          ...              ...
# 260  1400000US42003514000  42003514000          5140.00
# 261  1400000US42003550900  42003550900          5509.00
# 262  1400000US42003512800  42003512800          5128.00
# 263  1400000US42003513800  42003513800          5138.00
# 264  1400000US42003552100  42003552100          5521.00
#
#     Neighborhood_Municipality Additional_NeighMunis  Pop_Estimate  Tier  \
# 0               ROSSLYN FARMS             THORNBURG           983     1
# 1               SOUTH FAYETTE                   NaN          6726     1
# 2           UPPER SAINT CLAIR                   NaN          2522     1
# ...
